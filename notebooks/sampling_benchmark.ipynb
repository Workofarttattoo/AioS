# %%
# Thermal Sampling Benchmark (Phase 1)

from bio_q_sdk.state_vector import QuantumState
from bio_q_sdk.gates import H, CNOT
from bio_q_sdk.algorithms.thermal_sampling import ThermalSampler

# Prepare a two-qubit entangled state and walk under thermal noise
qs = QuantumState(2)
sampler = ThermalSampler(temperature_kelvin=300.0, spin_frequency_hz=2.87e9)
counts = sampler.sample(qs, steps=100, measure_qubits=[0, 1])
counts

# %%
# Thermal Sampling Benchmark (Phase 1)

from bio_q_sdk.state_vector import QuantumState
from bio_q_sdk.gates import H, CNOT
from bio_q_sdk.algorithms.thermal_sampling import ThermalSampler

# Two-qubit GHZ-like prep with thermal walk
qs = QuantumState(2)
sampler = ThermalSampler(temperature_kelvin=300.0)
counts = sampler.sample(qs, steps=100, measure_qubits=[0,1])
counts
